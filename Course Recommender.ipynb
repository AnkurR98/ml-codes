# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
dataset = pd.read_csv('./all-course-data.csv')

# %%
len(set(dataset.level))
# Out:
# 12

# %%
dataset.columns
# Out:
# Index(['course_index', 'course_title', 'url', 'certification', 'level',
#        'organization', 'platform'],
#       dtype='object')

# %%
dataset["difficulty"] = dataset["level"].map({"Advanced":100, "advanced":90, "All Levels":50, "Mixed":60, "Expert Level":80, "Intermediate": 40, "intermediate ":40, "intermediate":40, "Intermediate Level":45, "beginner":10, "Beginner":20, "Beginner Level":30})
set(dataset["difficulty"])
# Out:
# {10, 20, 30, 40, 45, 50, 60, 80, 90, 100}

# %%
dataset.drop("level", axis=1, inplace=True)

# %%
dataset.head(10)
# Out:
#    course_index                                       course_title  \
# 0             0                 Ultimate Investment Banking Course
# 1             1  Complete GST Course & Certification - Grow You...
# 2             2  Financial Modeling for Business Analysts and C...
# 3             3  Beginner to Pro - Financial Analysis in Excel ...
# 4             4       How To Maximize Your Profits Trading Options
# 5             5  Trading Penny Stocks: A Guide for All Levels I...
# 6             6  Investing And Trading For Beginners: Mastering...
# 7             7  Trading Stock Chart Patterns For Immediate, Ex...
# 8             8  Options Trading 3 : Advanced Stock Profit and ...
# 9             9  The Only Investment Strategy You Need For Your...
#
#                                                  url certification  \
# 0  https://www.udemy.com/ultimate-investment-bank...        COURSE
# 1      https://www.udemy.com/goods-and-services-tax/        COURSE
# 2  https://www.udemy.com/financial-modeling-for-b...        COURSE
# 3  https://www.udemy.com/complete-excel-finance-c...        COURSE
# 4  https://www.udemy.com/how-to-maximize-your-pro...        COURSE
# 5  https://www.udemy.com/trading-penny-stocks-a-g...        COURSE
# 6  https://www.udemy.com/investing-and-trading-fo...        COURSE
# 7  https://www.udemy.com/trading-chart-patterns-f...        COURSE
# 8  https://www.udemy.com/day-trading-stock-option...        COURSE
# 9  https://www.udemy.com/the-only-investment-stra...        COURSE
#
#        organization platform  difficulty
# 0  Business Finance    udemy          50
# 1  Business Finance    udemy          50
# 2  Business Finance    udemy          45
# 3  Business Finance    udemy          50
# 4  Business Finance    udemy          45
# 5  Business Finance    udemy          50
# 6  Business Finance    udemy          30
# 7  Business Finance    udemy          50
# 8  Business Finance    udemy          80
# 9  Business Finance    udemy          50

# %%
features = ["course_title", "course_index", "difficulty", "platform"]
def feature_combination(row):
    return row["course_title"] + " " + row["platform"] + " " + str(row["course_index"]) + " " + str(row["difficulty"])

dataset["cumulative_features"] = dataset.apply(feature_combination, axis = 1)

# %%
dataset
# Out:
#       course_index                                       course_title  \
# 0                0                 Ultimate Investment Banking Course
# 1                1  Complete GST Course & Certification - Grow You...
# 2                2  Financial Modeling for Business Analysts and C...
# 3                3  Beginner to Pro - Financial Analysis in Excel ...
# 4                4       How To Maximize Your Profits Trading Options
# 5                5  Trading Penny Stocks: A Guide for All Levels I...
# 6                6  Investing And Trading For Beginners: Mastering...
# 7                7  Trading Stock Chart Patterns For Immediate, Ex...
# 8                8  Options Trading 3 : Advanced Stock Profit and ...
# 9                9  The Only Investment Strategy You Need For Your...
# 10              10  Forex Trading Secrets of the Pros With Amazon'...
# 11              11                    Trading Options With Money Flow
# 12              12  Financial Management Risk and Return For Secur...
# 13              13  Forex Trading Course: Work Smarter Not Harder ...
# 14              14   Python Algo Trading: Sentiment Trading with News
# 15              15  Short Selling: Learn To Sell Stocks Before The...
# 16              16  Basic Technical Analysis: Learn the structure ...
# 17              17  The Complete Chart Pattern Trading Course: A P...
# 18              18  7 Deadly Mistakes of Investing that Will Slash...
# 19              19                     Financial Statements Made Easy
# 20              20  Winning Forex Trading with Live Forex Trading ...
# 21              21  Forex Traders - Create Your First Trading Robo...
# 22              22  Create A Business From Home Trading Stocks Tod...
# 23              23  Introduction to Accounting : Mastering Financi...
# 24              24  The Complete Ethereum Course: Get .01 Ether In...
# 25              25  Beginner to Pro in PowerPoint: Complete PowerP...
# 26              26  Investing 101: The Complete Online Investing C...
# 27              27  Create Your Own Hedge Fund: Trade Stocks Like ...
# 28              28  Learn MQL5: Build an 8-Currency Hedging Robot ...
# 29              29  Forex Trading: Your Complete Guide to Get Star...
# ...            ...                                                ...
# 4879           150  Setting up a Cloud Solution Environment on Goo...
# 4880           151  SharePoint Conference '19: Flowverload: The Wo...
# 4881           152    System Center Orchestrator 2012 R2 Fundamentals
# 4882           153                   T-SQL Data Manipulation Playbook
# 4883           154  TCP and UDP Operation for Cisco CCNA 200-125/1...
# 4884           155   TCP/IP and Networking Fundamentals for Sysadmins
# 4885           156                        TensorFlow: Getting Started
# 4886           157               The Information Security Big Picture
# 4887           158  Troubleshooting with Wireshark: Fundamental Pr...
# 4888           159                     Understanding Machine Learning
# 4889           160         Understanding Machine Learning with Python
# 4890           161              Understanding Machine Learning with R
# 4891           162       Understanding and Applying Linear Regression
# 4892           163  Understanding the Java Virtual Machine: Memory...
# 4893           164                            Unit Testing in Angular
# 4894           165     VMware Certified Associate - Cloud (VCA-Cloud)
# 4895           166                   VMware Cloud on AWS Fundamentals
# 4896           167                   VMware Cloud on AWS Fundamentals
# 4897           168  VMware NSX for vSphere Introduction and Instal...
# 4898           169         Visualizing Statistical Data Using Seaborn
# 4899           170            Web App Hacking: Hacking Authentication
# 4900           171                              What's New in Java 12
# 4901           172                               What's New in Java 9
# 4902           173            What's New in the OWASP Top 10 for 2013
# 4903           174           What’s New in Java 11: Long-term Support
# 4904           175        Windows Performance Monitoring Fundamentals
# 4905           176         Windows PowerShell Toolmaking Fundamentals
# 4906           177  Windows Server 2012 R2 (70-413) Server Deployment
# 4907           178  Windows Server Administration Fundamentals Usi...
# 4908           179           Working With Temporal Data in SQL Server
#
#                                                     url certification  \
# 0     https://www.udemy.com/ultimate-investment-bank...        COURSE
# 1         https://www.udemy.com/goods-and-services-tax/        COURSE
# 4907       pluralsight  pluralsight          20
# 4908       pluralsight  pluralsight          40
#
#                                     cumulative_features
# 0         Ultimate Investment Banking Course udemy 0 50
# 1     Complete GST Course & Certification - Grow You...
# 2     Financial Modeling for Business Analysts and C...
# 3     Beginner to Pro - Financial Analysis in Excel ...
# 4     How To Maximize Your Profits Trading Options u...
# 5     Trading Penny Stocks: A Guide for All Levels I...
# 6     Investing And Trading For Beginners: Mastering...
# 7     Trading Stock Chart Patterns For Immediate, Ex...
# 8     Options Trading 3 : Advanced Stock Profit and ...
# 9     The Only Investment Strategy You Need For Your...
# 10    Forex Trading Secrets of the Pros With Amazon'...
# 11          Trading Options With Money Flow udemy 11 50
# 12    Financial Management Risk and Return For Secur...
# 13    Forex Trading Course: Work Smarter Not Harder ...
# 14    Python Algo Trading: Sentiment Trading with Ne...
# 15    Short Selling: Learn To Sell Stocks Before The...
# 16    Basic Technical Analysis: Learn the structure ...
# 17    The Complete Chart Pattern Trading Course: A P...
# 18    7 Deadly Mistakes of Investing that Will Slash...
# 19           Financial Statements Made Easy udemy 19 30
# 20    Winning Forex Trading with Live Forex Trading ...
# 21    Forex Traders - Create Your First Trading Robo...
# 22    Create A Business From Home Trading Stocks Tod...
# 23    Introduction to Accounting : Mastering Financi...
# 24    The Complete Ethereum Course: Get .01 Ether In...
# 25    Beginner to Pro in PowerPoint: Complete PowerP...
# 26    Investing 101: The Complete Online Investing C...
# 27    Create Your Own Hedge Fund: Trade Stocks Like ...
# 28    Learn MQL5: Build an 8-Currency Hedging Robot ...
# 29    Forex Trading: Your Complete Guide to Get Star...
# ...                                                 ...
# 4879  Setting up a Cloud Solution Environment on Goo...
# 4880  SharePoint Conference '19: Flowverload: The Wo...
# 4881  System Center Orchestrator 2012 R2 Fundamental...
# 4882  T-SQL Data Manipulation Playbook pluralsight 1...
# 4883  TCP and UDP Operation for Cisco CCNA 200-125/1...
# 4884  TCP/IP and Networking Fundamentals for Sysadmi...
# 4885     TensorFlow: Getting Started pluralsight 156 20
# 4886  The Information Security Big Picture pluralsig...
# 4887  Troubleshooting with Wireshark: Fundamental Pr...
# 4888  Understanding Machine Learning pluralsight 159 20
# 4889  Understanding Machine Learning with Python plu...
# 4890  Understanding Machine Learning with R pluralsi...
# 4891  Understanding and Applying Linear Regression p...
# 4892  Understanding the Java Virtual Machine: Memory...
# 4893         Unit Testing in Angular pluralsight 164 20
# 4894  VMware Certified Associate - Cloud (VCA-Cloud)...
# 4895  VMware Cloud on AWS Fundamentals pluralsight 1...
# 4896  VMware Cloud on AWS Fundamentals pluralsight 1...
# 4897  VMware NSX for vSphere Introduction and Instal...
# 4898  Visualizing Statistical Data Using Seaborn plu...
# 4899  Web App Hacking: Hacking Authentication plural...
# 4900           What's New in Java 12 pluralsight 171 40
# 4901            What's New in Java 9 pluralsight 172 40
# 4902  What's New in the OWASP Top 10 for 2013 plural...
# 4903  What’s New in Java 11: Long-term Support plura...
# 4904  Windows Performance Monitoring Fundamentals pl...
# 4905  Windows PowerShell Toolmaking Fundamentals plu...
# 4906  Windows Server 2012 R2 (70-413) Server Deploym...
# 4907  Windows Server Administration Fundamentals Usi...
# 4908  Working With Temporal Data in SQL Server plura...
#
# [4909 rows x 8 columns]

# %%
cv = CountVectorizer()
_stopwords = stopwords.words('english')

# %%
user_preference = input("Input language/fav course : ")    #To come from front end of application
user_difficulty = 40

def tokenize_remove_stopwords(sentence):
    word_tokens = word_tokenize(sentence)
    word_tokens_cleaned = {word for word in word_tokens if word not in _stopwords}
    return ' '.join(list(word_tokens_cleaned))

user_preference_string = tokenize_remove_stopwords(user_preference).title()
print(user_preference_string)
# Out:
# Input language/fav course : Python
# Python

# %%
required_data = dataset[features]
print(len(required_data))
required_data.loc[len(required_data)] = [user_preference_string, len(required_data), user_difficulty, "None"]  #50 is default difficulty value. This will come from application
word_bag = cv.fit_transform(required_data["course_title"])
word_list = word_bag.toarray()
csim = cosine_similarity(word_list)
# Out:
# 4909
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
required_data.tail(5)
# Out:
#                                            course_title  course_index  \
# 4905         Windows PowerShell Toolmaking Fundamentals           176
# 4906  Windows Server 2012 R2 (70-413) Server Deployment           177
# 4907  Windows Server Administration Fundamentals Usi...           178
# 4908           Working With Temporal Data in SQL Server           179
# 4909                                             Python          4909
#
#       difficulty     platform
# 4905          40  pluralsight
# 4906          40  pluralsight
# 4907          20  pluralsight
# 4908          40  pluralsight
# 4909          40         None

# %%
similar_courses = list(enumerate(csim[len(required_data) - 1]))
sorted_similar_courses = sorted(similar_courses,key=lambda x:x[1],reverse=True)[1:50]
i=0
recommended_courses = dict()
for element in sorted_similar_courses:
    print(required_data.loc[element[0]])
    course = required_data.loc[element[0]]
    if(course["difficulty"] >= user_difficulty - 15 and course["difficulty"] <= user_difficulty + 15 and element[0] != len(required_data) - 1):
        recommended_courses[course["course_index"], course["platform"]] = 100 - abs(user_difficulty - course["difficulty"])
        
print(recommended_courses)
# Out:
# course_title    Python Basics
# course_index              682
# difficulty                 20
# platform             coursera
# Name: 4520, dtype: object
# course_title    Погружение в Python
# course_index                    885
# difficulty                       40
# platform                   coursera
# Name: 4723, dtype: object
# course_title    Python for Beginners: Python Programming Langu...
# course_index                                                 2681
# difficulty                                                     30
# platform                                                    udemy
# Name: 2681, dtype: object
# course_title    Introducción a la programación en Python I: Ap...
# course_index                                                  466
# difficulty                                                     20
# platform                                                 coursera
# Name: 4304, dtype: object
# course_title    Complete Python Web Course: Build 8 Python Web...
# course_index                                                 3138
# difficulty                                                     50
# platform                                                    udemy
# Name: 3138, dtype: object
# course_title    Python Web Programming
# course_index                      3343
# difficulty                          30
# platform                         udemy
# Name: 3343, dtype: object
# course_title    Python Data Structures
# course_index                       684
# difficulty                          60
# platform                      coursera
# Name: 4522, dtype: object
# course_title    Python for Everybody
# course_index                     688
# difficulty                        20
# platform                    coursera
# Name: 4526, dtype: object
# course_title    Statistics with Python
# course_index                       752
# difficulty                          20
# platform                      coursera
# Name: 4590, dtype: object
# course_title    Программирование на Python
# course_index                           886
# difficulty                              40
# platform                          coursera
# Name: 4724, dtype: object
# course_title    Python for Trading & Investing
# course_index                               536
# difficulty                                  50
# platform                                 udemy
# Name: 536, dtype: object
# course_title    Web Programming with Python
# course_index                           2497
# difficulty                               50
# platform                              udemy
# Name: 2497, dtype: object
# course_title    AI Programming with Python
# course_index                             2
# difficulty                              40
# platform                           udacity
# Name: 3680, dtype: object
# course_title    Introduction to Python Programming
# course_index                                   101
# difficulty                                      10
# platform                                   udacity
# Name: 3779, dtype: object
# course_title    Aprende a programar con Python
# course_index                                59
# difficulty                                  20
# platform                              coursera
# Name: 3897, dtype: object
# course_title    Crash Course on Python
# course_index                       171
# difficulty                          20
# platform                      coursera
# Name: 4009, dtype: object
# course_title    Data Analysis with Python
# course_index                          188
# difficulty                             20
# platform                         coursera
# Name: 4026, dtype: object
# course_title    Data Visualization with Python
# course_index                               203
# difficulty                                  40
# platform                              coursera
# Name: 4041, dtype: object
# course_title    Machine Learning with Python
# course_index                             570
# difficulty                                40
# platform                            coursera
# Name: 4408, dtype: object
# course_title    Python Classes and Inheritance
# course_index                               683
# difficulty                                  40
# platform                              coursera
# Name: 4521, dtype: object
# course_title    Using Databases with Python
# course_index                            849
# difficulty                               60
# platform                           coursera
# Name: 4687, dtype: object
# course_title    Основы программирования на Python
# course_index                                  883
# difficulty                                     20
# platform                                 coursera
# Name: 4721, dtype: object
# course_title    Python – Beyond the Basics
# course_index                           122
# difficulty                              40
# platform                       pluralsight
# Name: 4851, dtype: object
# course_title    Python: The Big Picture
# course_index                        123
# difficulty                           20
# platform                    pluralsight
# Name: 4852, dtype: object
# course_title    Stock Technical Analysis with Python
# course_index                                     334
# difficulty                                        50
# platform                                       udemy
# Name: 334, dtype: object
# course_title    Quantitative Trading Analysis with Python
# course_index                                          762
# difficulty                                             50
# platform                                            udemy
# Name: 762, dtype: object
# course_title    Investment Portfolio Analysis with Python
# course_index                                          863
# difficulty                                             50
# platform                                            udemy
# Name: 863, dtype: object
# course_title    Projects in Django and Python
# course_index                             2960
# difficulty                                 50
# platform                                udemy
# Name: 2960, dtype: object
# course_title    Introduction to QGIS Python Programming
# course_index                                       3333
# difficulty                                           30
# platform                                          udemy
# Name: 3333, dtype: object
# course_title    Applied Data Science with Python
# course_index                                  56
# difficulty                                    40
# platform                                coursera
# Name: 3894, dtype: object
# course_title    Applied Machine Learning in Python
# course_index                                    57
# difficulty                                      40
# platform                                  coursera
# Name: 3895, dtype: object
# course_title    Google IT Automation with Python
# course_index                                 391
# difficulty                                    20
# platform                                coursera
# Name: 4229, dtype: object
# course_title    Introduction to Scripting in Python
# course_index                                    513
# difficulty                                       20
# platform                                   coursera
# Name: 4351, dtype: object
# course_title    Python Functions, Files, and Dictionaries
# course_index                                          685
# difficulty                                             20
# platform                                         coursera
# Name: 4523, dtype: object
# course_title    Математика и Python для анализа данных
# course_index                                       880
# difficulty                                          20
# platform                                      coursera
# Name: 4718, dtype: object
# course_title    Core Python: Organizing Larger Programs
# course_index                                         30
# difficulty                                           40
# platform                                    pluralsight
# Name: 4759, dtype: object
# course_title    Getting Started with Python Concurrency
# course_index                                         62
# difficulty                                           20
# platform                                    pluralsight
# Name: 4791, dtype: object
# course_title    Understanding Machine Learning with Python
# course_index                                           160
# difficulty                                              20
# platform                                       pluralsight
# Name: 4889, dtype: object
# course_title    Learn Python and Django: Payment Processing
# course_index                                           2528
# difficulty                                               50
# platform                                              udemy
# Name: 2528, dtype: object
# course_title    Professional Python Web Development Using Flask
# course_index                                               3160
# difficulty                                                   30
# platform                                                  udemy
# Name: 3160, dtype: object
# course_title    Learn Python Django - A Hands-On Course
# course_index                                       3194
# difficulty                                           30
# platform                                          udemy
# Name: 3194, dtype: object
# course_title    REST APIs with Flask and Python
# course_index                               3203
# difficulty                                   45
# platform                                  udemy
# Name: 3203, dtype: object
# course_title    Programming for Data Science with Python
# course_index                                         128
# difficulty                                            40
# platform                                         udacity
# Name: 3806, dtype: object
# course_title    Data Collection and Processing with Python
# course_index                                           190
# difficulty                                              40
# platform                                          coursera
# Name: 4028, dtype: object
# course_title    Introduction to Data Science in Python
# course_index                                       487
# difficulty                                          40
# platform                                      coursera
# Name: 4325, dtype: object
# course_title    Python and Statistics for Financial Analysis
# course_index                                             686
# difficulty                                                40
# platform                                            coursera
# Name: 4524, dtype: object
# course_title    Python for Data Science and AI
# course_index                               687
# difficulty                                  20
# platform                              coursera
# Name: 4525, dtype: object
# course_title    Understanding and Visualizing Data with Python
# course_index                                               841
# difficulty                                                  20
# platform                                              coursera
# Name: 4679, dtype: object
# course_title    Using Python to Access Web Data
# course_index                                850
# difficulty                                   60
# platform                               coursera
# Name: 4688, dtype: object
# {(885, 'coursera'): 100, (2681, 'udemy'): 90, (3138, 'udemy'): 90, (3343, 'udemy'): 90, (886, 'coursera'): 100, (536, 'udemy'): 90, (2497, 'udemy'): 90, (2, 'udacity'): 100, (203, 'coursera'): 100, (570, 'coursera'): 100, (683, 'coursera'): 100, (122, 'pluralsight'): 100, (334, 'udemy'): 90, (762, 'udemy'): 90, (863, 'udemy'): 90, (2960, 'udemy'): 90, (3333, 'udemy'): 90, (56, 'coursera'): 100, (57, 'coursera'): 100, (30, 'pluralsight'): 100, (2528, 'udemy'): 90, (3160, 'udemy'): 90, (3194, 'udemy'): 90, (3203, 'udemy'): 95, (128, 'udacity'): 100, (190, 'coursera'): 100, (487, 'coursera'): 100, (686, 'coursera'): 100}
